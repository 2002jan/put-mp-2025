# %%
import cv2
import torch
from torchvision import transforms
from PIL import Image
import numpy as np
from app.utils.dataset import DepthDataset, create_data_loader
from models.train_depth_model import train_model
from app.utils.env import Env
import matplotlib.pyplot as plt
from models.UNet import UNet

# %%
env = Env()

image_size = 256
transform = transforms.Compose([
    transforms.Resize((256, 848)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

target_transform = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((256, 848)),
    transforms.ToTensor()
])

# %%
train_dataset = DepthDataset(
    root_dir=env.dataset_path / "train",
    transform=transform,
    target_transform=target_transform,
)
val_dataset = DepthDataset(
    root_dir=env.dataset_path / "val",
    transform=transform,
    target_transform=target_transform,
)

# %%
model = UNet()
train_loader = create_data_loader(train_dataset, batch_size=8)
val_loader = create_data_loader(val_dataset, batch_size=8, shuffle=False)

train_model(model, train_loader, val_loader, num_epochs=15)
# Out:
# Epoch 1/15
# Training: 100%|██████████| 546/546 [04:43<00:00,  1.93it/s]
# Validation: 100%|██████████| 44/44 [00:24<00:00,  1.81it/s]
# Train Loss: 1.1603380351057857 | Val Loss: 1.045225783361905
# Epoch 2/15
# Training: 100%|██████████| 546/546 [04:20<00:00,  2.10it/s]
# Validation: 100%|██████████| 44/44 [00:07<00:00,  6.16it/s]
# Train Loss: 1.0446308789017436 | Val Loss: 1.0281484037205793
# Epoch 3/15
# Training: 100%|██████████| 546/546 [04:21<00:00,  2.09it/s]
# Validation: 100%|██████████| 44/44 [00:07<00:00,  6.19it/s]
# Train Loss: 1.0078855948352115 | Val Loss: 1.0074680340462836
# Epoch 4/15
# Training: 100%|██████████| 546/546 [04:22<00:00,  2.08it/s]
# Validation: 100%|██████████| 44/44 [00:07<00:00,  6.12it/s]
# Train Loss: 0.9836252321908762 | Val Loss: 1.0011153915654059
# Epoch 5/15
# Training: 100%|██████████| 546/546 [04:27<00:00,  2.04it/s]
# Validation: 100%|██████████| 44/44 [00:07<00:00,  6.04it/s]
# Train Loss: 0.9626315440232064 | Val Loss: 0.9992335768713467
# Epoch 6/15
# Training: 100%|██████████| 546/546 [04:28<00:00,  2.04it/s]
# Validation: 100%|██████████| 44/44 [00:07<00:00,  6.13it/s]
# Train Loss: 0.9411583274275392 | Val Loss: 0.9937043435331704
# Epoch 7/15
# Training:   8%|▊         | 41/546 [00:20<04:11,  2.01it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       2 train_loader = create_data_loader(train_dataset, batch_size=8)
#       3 val_loader = create_data_loader(val_dataset, batch_size=8, shuffle=False)
# ----> 5 train_model(model, train_loader, val_loader, num_epochs=15)
#
# File ~\Desktop\pliki\MastersPUT\sem1\MP\repo\models\train_depth_model.py:115, in train_model(model, train_loader, val_loader, num_epochs, lr, device)
#     113 for epoch in range(1, num_epochs + 1):
#     114     print(f"Epoch {epoch}/{num_epochs}")
# --> 115     train_loss = train_one_epoch(model, train_loader, optimizer, loss_fn, device)
#     116     val_loss = evaluate(model, val_loader, loss_fn, device)
#     118     scheduler.step(val_loss)
#
# File ~\Desktop\pliki\MastersPUT\sem1\MP\repo\models\train_depth_model.py:80, in train_one_epoch(model, dataloader, optimizer, loss_fn, device)
#      78     loss.backward()
#      79     optimizer.step()
# ---> 80     running_loss += loss.item() * images.size(0)
#      82 return running_loss / len(dataloader.dataset)
#
# KeyboardInterrupt:

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# perform examplary inference
raw_image, depth_gt = train_dataset[0]  # raw_image and depth_gt are both tensors
raw_image = raw_image.unsqueeze(0).to(device)  # [1, 3, H, W]
depth_gt = depth_gt.squeeze().numpy()  # [H, W]

# %%
model.eval()
with torch.no_grad():
    prediction = model(raw_image)  # [1, 1, H, W]
    prediction = prediction.squeeze().cpu().numpy()  # [H, W]

# %%
import random

random.seed(23)

num_examples = 5
fig = plt.figure(figsize=(20, 3 * num_examples))

for i in range(num_examples):
    idx = random.randint(0, len(train_dataset) - 1)
    raw_image, depth_image = train_dataset[idx]
    raw_image = raw_image.unsqueeze(0).to(device)  # [1, 3, H, W]
    with torch.no_grad():
        prediction = model(raw_image)
        prediction = prediction.squeeze().cpu().numpy()

    ax = fig.add_subplot(num_examples, 3, i * 3 + 1)
    ax.imshow(raw_image.squeeze().permute(1, 2, 0).cpu(), cmap='plasma')
    ax.set_title("Raw Image")
    ax.axis('off')

    ax = fig.add_subplot(num_examples, 3, i * 3 + 2)
    ax.imshow(prediction, cmap='plasma')
    ax.set_title("Predicted Depth")
    ax.axis('off')

    ax = fig.add_subplot(num_examples, 3, i * 3 + 3)
    ax.imshow(depth_image.permute(1, 2, 0).numpy() * 255, cmap='plasma')
    ax.set_title("Ground Truth Depth")
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
